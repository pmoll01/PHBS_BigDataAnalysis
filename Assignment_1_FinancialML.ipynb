# %% [markdown]
# # Assignment 1 - ML in Finance
# - In Assignment 1, you are required to implement several machine learning models to predict future stock return based on some characteristics.
# - Before you start, please read the empirical setting part of Gu, Kelly, and Xiu (2020). We will basically follow the same setting in this assignment.

# %% [markdown]
# # Step 0 - Set the stage
# - Import libraries.
# - Set a working directory.
# - If in later steps, you find your machine is slow to run the code, you may need to reduce the size of the data by selecting a subset of the data.
#     * If so, edit this markdown and put an "X" in the checkbox below.
#     * [ ] Yes, I need to reduce the sample size.
#     * Then, only keep permno code that satisfies $permno\%x \le y$. For example, if you want to keep 50% data, the condition should be something like "$permno\%10 \le 4$". Put your $x$ and $y$ here if you want to reduce the sample size.

# %% [markdown]
# # Step 1 - Load the data
# (1) Load the csv file of firm characteristics and monthly stock return.
# - The firm characteristics data can be obtained from Dacheng Xiu's website. You will have a csv file "datashare.csv", and a readme file "readme.txt".
# - The monthly stock return data can be obtained from CRSP.
# - Although the original paper uses macro variables and industry dummies, we will not use them in this assignment.
#
# (2) After you successfully load the data, merge them. Then report a summary statistics of the data by calling the describe() function.
# - For how to merge, remember to check "readme.txt".
# - For summary statistics, just focus on stock return, date, and three characteristics: "mom12m", "mvel1", and "bm".
#
# (3) Then describe *very briefly* what do you observe from the summary statistics (i. e., what kind of things do we need to pay attention to)

# %% [markdown]
# # Step 2 - Clean the data
# - Generate a time indicator "ym" for both tables, which equals year*12 + month.
# - Drop duplicates by "permno" and "ym" using the .drop_duplicates() function.
# - Check Gu, Kelly, and Xiu (2020) footnote 29 and 30 for rank normalization and filling missing values. Perform the cleaning.

# %% [markdown]
# # Step 3 - Basic portfolio analysis
# - For each of the three variables in "mom12m", "mvel1", and "bm", write a function that:
#   - Sort stocks at each cross section by the variable in ascending order, and rank them into 10 groups.
#   - Calculate the EW average return and VW return of each group.
#   - Calculate the 10-1 return spread.
#   - Calculate the Sharpe ratio, the average monthly return, and plot the cumulative return.
# - Describe *very briefly* what do you find in the results.

# %% [markdown]
# # Step 4 - ML with training-validation-test design
# - Check the rolling-window training design in Gu, Kelly, and Xiu (2020).
# - Pick two models among (to pick, edit this markdown and put an "X" in the checkbox):
#     * [ ] ENet
#     * [ ] PCR
#     * [ ] PLS
#     * [ ] RF
#     * [ ] GBRT
# - Or, if you would like to try other models (such as NN3, GLM; OLS is not included), write down here:
#     * [X] Model Name
# - For each model you choose, implement the rolling-window training design in Gu, Kelly, and Xiu (2020), with hyperparameter choosing. Be careful that hyperparameters to be tuned differ among models.
#     * You need to report the "Monthly out-of-sample stock-level prediction performance" ($R^2_{OOS}$) as in Table 1,
#     * And "Performance of the machine learning portfolios" as in Table 7.

# %% [markdown]
# # About evaluation
# - Evaluation of this coding assignment will be based on the following criteria:
#     - Code quality: The code should be well-organized, easy to read, and presented in a logical way.
#     - Correctness: The code should follow the instructions and the paper. Final results can differ, which is acceptable (but the results should at least make sense).
# - Step 1: 2 pts
# - Step 2: 2 pts
# - Step 3: 2 pts
# - Step 4: 5 pts
# - Overall readability: 4 pts
# - Total: 15 pts

# %% [markdown]
# - Using AI coding tools will not affect the evaluation. But if you use AI coding, please submit with this assignment your screenshots on how you interact with the AI tools.

# %% [markdown]
# # Good Luck!
# - DDL is when we announce the next coding assignment (typically 2 weeks later)
